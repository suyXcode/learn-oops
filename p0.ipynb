# %% [markdown]
# # OOPs (Object-Oriented Programming System)
#
# **🌟 What is OOP?**
#
# - OOP (Object-Oriented Programming) is a programming paradigm based on the concept of objects — entities that contain data (attributes) and behavior (methods).
# - It helps make code modular, reusable, scalable, and easier to maintain.
#
#
# **🧱 Class :**
#
# - A class is a blueprint or template for creating objects.
# - It defines attributes (variables) and methods (functions) that describe the object’s behavior.
#
# 👉 Think of a class like a “Car design” — not an actual car, just the design.
#
#
# **🚗 Object :**
#
# An object is an instance of a class — a real-world entity created using the class.
# Each object has its own data (attributes) and can call the methods of the class.
#
# 👉 Think of an object like an actual “Car” made from the design.
#
#
# **🔑 4 Main Pillars of OOP**
#
# **1️⃣ Encapsulation — Data Hiding**
#
# - Definition:
#
# Encapsulation is the concept of wrapping data and methods that operate on that data into a single unit (class).
# It also restricts direct access to some variables — this is known as data hiding.
#
# **2️⃣ Inheritance — Code Reusability**
#
# - Definition:
#
# Inheritance allows a class (child) to inherit attributes and methods from another class (parent).
# It promotes code reusability.
#
# **3️⃣ Polymorphism — Many Forms**
#
# - Definition:
# -
# Polymorphism means many forms — the same function name can be used for different types of objects.
#
# Example 1: Function Overriding (Runtime Polymorphism)
#
# **4️⃣ Abstraction — Hiding Details**
#
# - Definition:
#
# Abstraction means hiding complex implementation details and showing only the necessary features.
# In Python, abstraction is achieved using abstract classes and methods (from the abc module).
#
# # 🔹 2️⃣ Class Members and Object Members
#
# **🔸 Class Members (Class Variables)**
#
# - Shared by all objects of the class.
# - Declared inside the class but outside methods.
# - Accessed using ClassName.variable_name.
#
# **🔸 Object Members (Instance Variables)**
#
# - Belong to each individual object.
# - Created inside the constructor (__init__) or methods using self.
# - Accessed with object_name.variable_name.
#
#
# # ⚙️ 3️⃣ Types of Methods in a Class
#
# There are three main types of methods:
#
# **🧠 (i) Instance Method**
#
# - Operates on instance variables.
# - First parameter is always self.
# - Accessed by using object name.
#
#
# **🏫 (ii) Class Method**
#
# - Works with class variables.
# - Decorated with @classmethod.
# - Takes cls (class reference) as the first argument.
# - Accessed by class name or object.
#
# **🧰 (iii) Static Method**
#
# - Does not depend on instance or class variables.
# - Defined using @staticmethod.
# - Can be used for utility work.

# %% [markdown]
# # ✅ Final Summary
# ---
#
#
# | Concept             | Description                     | Example Keyword         |
# | ------------------- | ------------------------------- | ----------------------- |
# | **Class**           | Blueprint for objects           | `class`                 |
# | **Object**          | Instance of a class             | `obj = Class()`         |
# | **Class Member**    | Shared variable for all objects | `ClassName.var`         |
# | **Object Member**   | Unique per object               | `self.var`              |
# | **Instance Method** | Works on instance data          | `def method(self):`     |
# | **Class Method**    | Works on class data             | `@classmethod`          |
# | **Static Method**   | Utility method                  | `@staticmethod`         |
# | **Encapsulation**   | Data hiding                     | `__private`             |
# | **Inheritance**     | Reuse parent class code         | `class Child(Parent)`   |
# | **Polymorphism**    | Same name, different behavior   | `method overriding`     |
# | **Abstraction**     | Hiding complexity               | `ABC`, `abstractmethod` |
